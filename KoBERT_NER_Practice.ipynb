# %% [markdown]
# <a href="https://colab.research.google.com/github/alfrizzle/NLP-Projects/blob/master/KoBERT_NER_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/monologg/KoBERT-NER.git

# %%
import os
# !pwd
# Out:
# /content

# %%
os.chdir('/content/drive/MyDrive/KoBERT-NER-master')
# !pwd
# Out:
# /content/drive/MyDrive/KoBERT-NER-master

# %%
# !ls
# Out:
# data		model	     requirements.txt	     trainer.py
# data_loader.py	predict.py   sample_pred_in.txt      utils.py
# LICENSE		__pycache__  sample_pred_out.txt
# main.py		README.md    tokenization_kobert.py

# %%
# !pip install transformers==2.10.0
# Out:
# ...
#      |████████████████████████████████| 665kB 3.9MB/s
# ...
#      |████████████████████████████████| 5.6MB 23.7MB/s
# ...
#      |████████████████████████████████| 901kB 31.7MB/s
# ...
#      |████████████████████████████████| 1.2MB 32.0MB/s
# ...

# %%
# !pip install seqeval
# Out:
# ...
#      |████████████████████████████████| 51kB 4.3MB/s
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-cp37-none-any.whl size=16184 sha256=4866e20468b7e886ba8983eda7a3bba56b1d06e123bed29de421d5d8c1583f32
#   Stored in directory: /root/.cache/pip/wheels/52/df/1b/45d75646c37428f7e626214704a0e35bd3cfc32eda37e59e5f
# Successfully built seqeval
# ...

# %%
# !python main.py --do_train --do_eval --num_train_epochs 20
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration:  84% 2137/2532 [03:59<00:39,  9.96it/s]
# Iteration:  84% 2139/2532 [04:00<00:39, 10.01it/s]
# Iteration:  85% 2141/2532 [04:00<00:39, 10.02it/s]
# Iteration:  85% 2143/2532 [04:00<00:38, 10.06it/s]
# Iteration:  85% 2145/2532 [04:00<00:38, 10.08it/s]
# Iteration:  85% 2147/2532 [04:00<00:38, 10.06it/s]
# Iteration:  85% 2149/2532 [04:01<00:38, 10.06it/s]
# Iteration:  85% 2151/2532 [04:01<00:37, 10.06it/s]
# Iteration:  85% 2153/2532 [04:01<00:37, 10.06it/s]
# Iteration:  85% 2155/2532 [04:01<00:37,  9.99it/s]
# Iteration:  85% 2156/2532 [04:01<00:37,  9.97it/s]
# Iteration:  85% 2157/2532 [04:01<00:37,  9.97it/s]
# Iteration:  85% 2158/2532 [04:02<00:37,  9.97it/s]
# Iteration:  85% 2159/2532 [04:02<00:37,  9.96it/s]
# Iteration:  85% 2160/2532 [04:02<00:37,  9.97it/s]
# Iteration:  85% 2162/2532 [04:02<00:36, 10.00it/s]
# Iteration:  85% 2164/2532 [04:02<00:36, 10.05it/s]
# ...

# %%
# !python main.py --do_train --do_eval --num_train_epochs 5
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration:  55% 1403/2532 [04:36<03:27,  5.43it/s]07/01/2021 01:16:15 - INFO - trainer -   ***** Running evaluation on test dataset *****
# 07/01/2021 01:16:15 - INFO - trainer -     Num examples = 9000
# 07/01/2021 01:16:15 - INFO - trainer -     Batch size = 64
#
#
# Evaluating:   0% 0/141 [00:00<?, ?it/s]
#
# Evaluating:   1% 2/141 [00:00<00:13, 10.18it/s]
#
# Evaluating:   3% 4/141 [00:00<00:13, 10.18it/s]
#
# Evaluating:   4% 6/141 [00:00<00:13, 10.18it/s]
#
# Evaluating:   6% 8/141 [00:00<00:13, 10.14it/s]
#
# Evaluating:   7% 10/141 [00:00<00:12, 10.11it/s]
#
# Evaluating:   8% 11/141 [00:01<00:12, 10.08it/s]
#
# Evaluating:   9% 13/141 [00:01<00:12, 10.06it/s]
#
# Evaluating:  10% 14/141 [00:01<00:12, 10.04it/s]
#
# Evaluating:  11% 15/141 [00:01<00:12,  9.99it/s]
#
# Evaluating:  11% 16/141 [00:01<00:12,  9.98it/s]
#
# Evaluating:  12% 17/141 [00:01<00:12,  9.98it/s]
#
# Evaluating:  13% 18/141 [00:01<00:12,  9.93it/s]
#
# ...

# %%
# !python main.py --do_train --do_eval --num_train_epochs 1 --logging_steps 10 --save_steps 10
# Out:
# 2021-07-01 01:56:10.678853: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 07/01/2021 01:56:12 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/monologg/kobert/tokenizer_78b3253a26.model from cache at /root/.cache/torch/transformers/1f871cf1d80a4c09742b5f2094cc7ab9163dfbcfb930d99fdc9149aebf6a13bb.7555cd8e0e341a4d19f33dcb20eaf8614c72f56827d1b28481046caabba18eb3
# 07/01/2021 01:56:12 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/monologg/kobert/vocab.txt from cache at /root/.cache/torch/transformers/c247d0225676d99ae7f3e6d39dba68b77756181415828f922c6393e4aecb53ce.5d8505da4be274704344000e8d9a798ff03b513f5053f98f7e97d719a9a9891b
# 07/01/2021 01:56:12 - INFO - data_loader -   Loading features from cached file ./data_02/cached_naver-ner_v2_kobert_50_test
# ...

# %%
# !python main.py --do_train --do_eval --num_train_epochs 10 --logging_steps 250 --save_steps 250
# Out:
# 2021-07-01 02:03:57.844884: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 07/01/2021 02:04:00 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/monologg/kobert/tokenizer_78b3253a26.model from cache at /root/.cache/torch/transformers/1f871cf1d80a4c09742b5f2094cc7ab9163dfbcfb930d99fdc9149aebf6a13bb.7555cd8e0e341a4d19f33dcb20eaf8614c72f56827d1b28481046caabba18eb3
# 07/01/2021 02:04:00 - INFO - transformers.tokenization_utils -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/monologg/kobert/vocab.txt from cache at /root/.cache/torch/transformers/c247d0225676d99ae7f3e6d39dba68b77756181415828f922c6393e4aecb53ce.5d8505da4be274704344000e8d9a798ff03b513f5053f98f7e97d719a9a9891b
# 07/01/2021 02:04:00 - INFO - data_loader -   Loading features from cached file ./data_02/cached_naver-ner_v2_kobert_50_test
# ...

# %%
# !python predict.py
# Out:
# 2021-06-29 19:47:46.028337: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 06/29/2021 19:47:47 - INFO - transformers.configuration_utils -   loading configuration file ./model/config.json
# 06/29/2021 19:47:47 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "architectures": [
#     "BertForTokenClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "naver-ner",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "UNK",
#     "1": "O",
#     "2": "PER-B",
#     "3": "PER-I",
#     "4": "FLD-B",
#     "5": "FLD-I",
#     "6": "AFW-B",
#     "7": "AFW-I",
#     "8": "ORG-B",
#     "9": "ORG-I",
#     "10": "LOC-B",
#     "11": "LOC-I",
#     "12": "CVL-B",
#     "13": "CVL-I",
#     "14": "DAT-B",
#     "15": "DAT-I",
#     "16": "TIM-B",
#     "17": "TIM-I",
#     "18": "NUM-B",
# ...
